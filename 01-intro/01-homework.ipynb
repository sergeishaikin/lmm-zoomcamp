# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
import os

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[{"role": "user", "content": "It's too late to join the course?"}]
    
)

# %%
print(response.choices[0].message.content)
# Out:
# I'm not sure which course you're referring to, but it's always best to check with the course provider or institution for specific enrollment deadlines. If it's too late for the current session, you might want to ask if there are waiting lists, future sessions, or similar courses available. Many educational organizations offer online resources, recordings, or self-paced options if you're looking to get started right away.
